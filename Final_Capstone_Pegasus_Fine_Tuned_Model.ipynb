# %% [markdown]
# <a href="https://colab.research.google.com/github/Srividhyak2011/Demo-Datascienceproject/blob/main/Final_Capstone_Pegasus_Fine_Tuned_Model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
data = pd.read_csv('/content/Playstore_Google_Apps_User_Review_Updated.csv')

# %%
data.head()
# Out:
#                userName                                            content  \
# 0               Mor Mir  Working with this app is so difficult. Default...
# 1         Yashraj Pawar  I would give it 0 stars if possible. No option...
# 2       BIKASH SIWAKOTI  Dear Google.. I found a very critical bug..cus...
# 3  SAMBASIVA RAO JANGAM  Worst interface ever......can't even add a new...
# 4                Haroon  While opening a saved contact entry, this app ...
#
#   replyContent
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 95002 entries, 0 to 95001
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   userName      95002 non-null  object
#  1   content       94994 non-null  object
#  2   replyContent  11568 non-null  object
# dtypes: object(3)
# memory usage: 2.2+ MB

# %%
data.dropna(inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11568 entries, 1201 to 94598
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   userName      11568 non-null  object
#  1   content       11568 non-null  object
#  2   replyContent  11568 non-null  object
# dtypes: object(3)
# memory usage: 361.5+ KB

# %%
data.drop_duplicates(inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10252 entries, 1201 to 94598
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   userName      10252 non-null  object
#  1   content       10252 non-null  object
#  2   replyContent  10252 non-null  object
# dtypes: object(3)
# memory usage: 320.4+ KB

# %%
data["Input"] = data[["userName", "content"]].apply(" - ".join, axis=1)

# %%
data.head()
# Out:
#                userName                                            content  \
# 1201        dave wagner  My phone NEVER rings when I get a phone call. ...
# 1202  Sachin Prabhashan  Sometimes unable switch loudspeaker mode. some...
# 1203      Crystal Adams  I wasn't able to on this one, and NEVER ON THE...
# 1204   Janet Braunstein  App no longer works; can't use the phone... Go...
# 1205   Swaroop Poonater  Call logs are very weird and doesn't make any ...
#
#                                            replyContent  \
# 1201  Hi, Dave. We're sorry to hear that. Let's try ...
# 1202  Hi, Sachin. We're sorry to hear that. Let's tr...
# 1203  Hi, Crystal. We're sorry to hear that. Let's t...
# 1204  Hi, Janet. Try restarting your phone and make ...
# 1205  Hi, Swaroop. We're sorry to hear that. The tea...
#
#                                                   Input
# 1201  dave wagner - My phone NEVER rings when I get ...
# 1202  Sachin Prabhashan - Sometimes unable switch lo...
# ...

# %%
data = data.drop(columns=['userName'])
data = data.drop(columns=['content'])

# %%
data.head()
# Out:
#                                            replyContent  \
# 1201  Hi, Dave. We're sorry to hear that. Let's try ...
# 1202  Hi, Sachin. We're sorry to hear that. Let's tr...
# 1203  Hi, Crystal. We're sorry to hear that. Let's t...
# 1204  Hi, Janet. Try restarting your phone and make ...
# 1205  Hi, Swaroop. We're sorry to hear that. The tea...
#
#                                                   Input
# 1201  dave wagner - My phone NEVER rings when I get ...
# 1202  Sachin Prabhashan - Sometimes unable switch lo...
# 1203  Crystal Adams - I wasn't able to on this one, ...
# 1204  Janet Braunstein - App no longer works; can't ...
# 1205  Swaroop Poonater - Call logs are very weird an...

# %%
# Using drop() function to delete first n rows
n=9000
data.drop(index=data.index[:n],axis=0, inplace=True)
print(data)
# Out:
#                                             replyContent  \
# 81914  Hi, Stefan. For your privacy, we can't trouble...
# 81915  Hi, Shimmy. We're working on adding more featu...
# 81916  Hi, Eugenia. If your account is eligible, you ...
# 81918  Hi, Calo. For your privacy, we can't troublesh...
# 81919  Hi Michael. Thanks for reaching out about that...
# ...                                                  ...
# 94584  Thank you for your feedback. We've now launche...
# 94593  Thank you for your feedback. We've now launche...
# 94595  Thank you for your feedback. We've now launche...
# 94597  Thank you for your feedback. We've now launche...
# 94598  Thank you for your feedback. We've now launche...
#
#                                                    Input
# 81914  Stefan Farrington - The VPN shortcut no longer...
# 81915  Shimmy Weitzhandler - Hi, Please improve the "...
# 81916  Eugenia Tirado - I can't buy more space I'm tr...
# ...

# %%
pip install transformers datasets

# %%
# !pip install sentencepiece

# %%
# !pip install accelerate -U

# %%
# !pip install transformers[torch]

# %%
# !pip install sklearn
# Out:
# ...
#   Using cached sklearn-0.0.post11.tar.gz (3.6 kB)
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Preparing metadata (setup.py) ... error
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.

# %%
import sklearn.model_selection
train, test = sklearn.model_selection.train_test_split(data, test_size=0.2, random_state=42, shuffle=True)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1001 entries, 88761 to 93632
# Data columns (total 2 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   replyContent  1001 non-null   object
#  1   Input         1001 non-null   object
# dtypes: object(2)
# memory usage: 23.5+ KB

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 251 entries, 89417 to 92621
# Data columns (total 2 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   replyContent  251 non-null    object
#  1   Input         251 non-null    object
# dtypes: object(2)
# memory usage: 5.9+ KB

# %%
"""Script for fine-tuning Pegasus
Example usage:
  # use XSum dataset as example, with first 1000 docs as training data
  from datasets import load_dataset
  dataset = load_dataset("xsum")
  train_texts, train_labels = dataset['train']['document'][:1000], dataset['train']['summary'][:1000]

  # use Pegasus Large model as base for fine-tuning
  model_name = 'google/pegasus-large'
  train_dataset, _, _, tokenizer = prepare_data(model_name, train_texts, train_labels)
  trainer = prepare_fine_tuning(model_name, tokenizer, train_dataset)
  trainer.train()

Reference:
  https://huggingface.co/transformers/master/custom_datasets.html
"""

from transformers import PegasusForConditionalGeneration, PegasusTokenizer, Trainer, TrainingArguments
import torch


class PegasusDataset(torch.utils.data.Dataset):
    def __init__(self, encodings, labels):
        self.encodings = encodings
        self.labels = labels
    def __getitem__(self, idx):
        item = {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
        item['labels'] = torch.tensor(self.labels['input_ids'][idx])  # torch.tensor(self.labels[idx])
        return item
    def __len__(self):
        return len(self.labels['input_ids'])  # len(self.labels)


def prepare_data(model_name,
                 train_texts, train_labels,
                 val_texts=None, val_labels=None,
                 test_texts=None, test_labels=None):
  """
  Prepare input data for model fine-tuning
  """
  tokenizer = PegasusTokenizer.from_pretrained(model_name)

  prepare_val = False if val_texts is None or val_labels is None else True
  prepare_test = False if test_texts is None or test_labels is None else True

  def tokenize_data(texts, labels):
    encodings = tokenizer(texts, truncation=True, padding=True)
    decodings = tokenizer(labels, truncation=True, padding=True)
    dataset_tokenized = PegasusDataset(encodings, decodings)
    return dataset_tokenized

  train_dataset = tokenize_data(train_texts, train_labels)
  val_dataset = tokenize_data(val_texts, val_labels) if prepare_val else None
  test_dataset = tokenize_data(test_texts, test_labels) if prepare_test else None

  return train_dataset, val_dataset, test_dataset, tokenizer


def prepare_fine_tuning(model_name, tokenizer, train_dataset, val_dataset=None, freeze_encoder=False, output_dir='./results'):
  """
  Prepare configurations and base model for fine-tuning
  """
  torch_device = 'cuda' if torch.cuda.is_available() else 'cpu'
  model = PegasusForConditionalGeneration.from_pretrained(model_name).to(torch_device)

  if freeze_encoder:
    for param in model.model.encoder.parameters():
      param.requires_grad = False

  if val_dataset is not None:
    training_args = TrainingArguments(
      output_dir=output_dir,           # output directory
      num_train_epochs=2,           # total number of training epochs
      per_device_train_batch_size=15,   # batch size per device during training, can increase if memory allows
      per_device_eval_batch_size=15,    # batch size for evaluation, can increase if memory allows
      save_steps=1,                  # number of updates steps before checkpoint saves
      save_total_limit=1,              # limit the total amount of checkpoints and deletes the older checkpoints
      evaluation_strategy='steps',     # evaluation strategy to adopt during training
      eval_steps=1,                  # number of update steps before evaluation
      warmup_steps=1,                # number of warmup steps for learning rate scheduler
      weight_decay=0.01,               # strength of weight decay
      logging_dir='./logs',            # directory for storing logs
      logging_steps=10,
    )

    trainer = Trainer(
      model=model,                         # the instantiated 🤗 Transformers model to be trained
      args=training_args,                  # training arguments, defined above
      train_dataset=train_dataset,         # training dataset
      eval_dataset=val_dataset,            # evaluation dataset
      tokenizer=tokenizer
    )

  else:
    training_args = TrainingArguments(
      output_dir=output_dir,           # output directory
      num_train_epochs=2,           # total number of training epochs
      per_device_train_batch_size=15,   # batch size per device during training, can increase if memory allows
      save_steps=1,                  # number of updates steps before checkpoint saves
      save_total_limit=1,              # limit the total amount of checkpoints and deletes the older checkpoints
      warmup_steps=1,                # number of warmup steps for learning rate scheduler
      weight_decay=0.01,               # strength of weight decay
      logging_dir='./logs',            # directory for storing logs
      logging_steps=10,
    )

    trainer = Trainer(
      model=model,                         # the instantiated 🤗 Transformers model to be trained
      args=training_args,                  # training arguments, defined above
      train_dataset=train_dataset,         # training dataset
      tokenizer=tokenizer
    )

  return trainer


if __name__=='__main__':
  # use XSum dataset as example, with first 1000 docs as training data
  #from datasets import load_dataset
  #dataset = load_dataset("xsum")
  train_texts, train_labels = train['Input'].tolist(), train['replyContent'].tolist()

  # use Pegasus Large model as base for fine-tuning
  model_name = 'google/pegasus-large'
  train_dataset, _, _, tokenizer = prepare_data(model_name, train_texts, train_labels)
  trainer = prepare_fine_tuning(model_name, tokenizer, train_dataset)
  trainer.train()
# Out:
# Some weights of PegasusForConditionalGeneration were not initialized from the model checkpoint at google/pegasus-large and are newly initialized: ['model.decoder.embed_positions.weight', 'model.encoder.embed_positions.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#     <div>
#
#       <progress value='134' max='134' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [134/134 1:33:37, Epoch 2/2]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>10</td>
#       <td>8.822800</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>7.843500</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>7.293000</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>6.746000</td>
#     </tr>
#     <tr>
# ...

# %%
from transformers import PegasusForConditionalGeneration, PegasusTokenizer

# Load fine-tuned PEGASUS model and tokenizer
model_name = "/content/results/checkpoint-134"  # Path to your fine-tuned model
model = PegasusForConditionalGeneration.from_pretrained(model_name)
tokenizer = PegasusTokenizer.from_pretrained(model_name)

# Generate summaries for each email in the test DataFrame
generated_summaries = []

for email_text in test['Input']:
    inputs = tokenizer(email_text, return_tensors='pt', max_length=1024, truncation=True)
    summary_ids = model.generate(inputs.input_ids, max_length=150, num_beams=4, length_penalty=2.0, early_stopping=True)
    generated_summary = tokenizer.decode(summary_ids[0], skip_special_tokens=True)
    generated_summaries.append(generated_summary)

# Add generated summaries to the DataFrame
test['Generated_Summary'] = generated_summaries

# Tokenize the input text
#inputs = tokenizer(input_text, return_tensors="pt", max_length=1024, truncation=True)

# Generate summary using the model
#summary_ids = model.generate(inputs.input_ids, max_length=150, num_beams=4, length_penalty=2.0, early_stopping=True)

# Decode and print the generated summary
#generated_summary = tokenizer.decode(summary_ids[0], skip_special_tokens=True)
#print("Generated Summary:")
#print(generated_summary)

# %%
pip install rouge-score
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for rouge-score: filename=rouge_score-0.1.2-py3-none-any.whl size=24933 sha256=13f5e9cd0298fa1f53d8f9ae7f93ced08848310f5e20a41e12110d6d873dc5e1
#   Stored in directory: /root/.cache/pip/wheels/5f/dd/89/461065a73be61a532ff8599a28e9beef17985c9e9c31e541b4
# Successfully built rouge-score
# ...

# %%
from rouge_score import rouge_scorer

# Example generated summaries and reference summaries from the test data
generated_summaries = test['Generated_Summary']
reference_summaries = test['replyContent']  # Assuming you have a 'replyContent' column

scorer = rouge_scorer.RougeScorer(['rouge1', 'rougeL'], use_stemmer=True)

# Calculate ROUGE scores for each generated summary compared to its reference summary
scores = []
rouge1_scores = []
rougeL_scores = []

for generated, reference in zip(generated_summaries, reference_summaries):
    rouge_scores = scorer.score(generated, reference)
    scores.append(rouge_scores)
    rouge1_scores.append(rouge_scores['rouge1'].fmeasure)
    rougeL_scores.append(rouge_scores['rougeL'].fmeasure)

# Add ROUGE scores as new columns to the DataFrame
test['ROUGE-1'] = rouge1_scores
test['ROUGE-L'] = rougeL_scores

# Calculate average ROUGE scores
rouge1_f1 = sum(score['rouge1'].fmeasure for score in scores) / len(scores)
rougeL_f1 = sum(score['rougeL'].fmeasure for score in scores) / len(scores)

print(f"Average ROUGE-1 F1 Score: {rouge1_f1}")
print(f"Average ROUGE-L F1 Score: {rougeL_f1}")
# Out:
# Average ROUGE-1 F1 Score: 0.31215874112604447
# Average ROUGE-L F1 Score: 0.2648582832284202

# %%
pip install python-Levenshtein
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 169.4/169.4 kB 3.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 11.4 MB/s eta 0:00:00
# ...

# %%
import Levenshtein

# Compute Word Error Rate (WER) and Character Error Rate (CER) for each pair of texts
wer_scores = []
cer_scores = []

for gen_text, ref_text in zip(test['Generated_Summary'], test['replyContent']):
    gen_words = gen_text.split()
    ref_words = ref_text.split()

    # Calculate WER
    wer = Levenshtein.distance(gen_words, ref_words) / len(ref_words)
    wer_scores.append(wer)

    # Calculate CER
    cer = Levenshtein.distance(gen_text, ref_text) / len(ref_text)
    cer_scores.append(cer)

# Add WER and CER scores as new columns to the DataFrame
test['WER'] = wer_scores
test['CER'] = cer_scores


# Compute average WER and CER
average_wer = sum(wer_scores) / len(wer_scores)
average_cer = sum(cer_scores) / len(cer_scores)

print(f"Average Word Error Rate (WER): {average_wer}")
print(f"Average Character Error Rate (CER): {average_cer}")
# Out:
# Average Word Error Rate (WER): 0.9453809487115121
# Average Character Error Rate (CER): 0.7598971120332088

# %%
train.to_csv('/train.csv', index=False)
test.to_csv('/test.csv', index=False)
